# %%
# !pip install joblib

# %%
#import libs & dependancies
import numpy as np 
import pandas as pd 
import sklearn.svm as svm 
import datetime 
from sklearn.model_selection import train_test_split 
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.preprocessing import RobustScaler
from sklearn.externals import joblib
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.svm import SVR

# %%
#load data set 
# data sets contain historical weather data on x location
# incluedes variables such as humidity, wind & 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-198488d5-0960-473a-9608-a1307274578a" name="files[]" multiple disabled />
#      <output id="result-198488d5-0960-473a-9608-a1307274578a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather data.csv to weather data (1).csv

# %%
#read data 
weatherData = pd.read_csv('weather data (1).csv')
#show sample of the data to ensure that its been read correctly
weatherData.head(10)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 80
#           day  tempMin  tempMax  ...  humidity windSpeed visibility
# 0  01/01/2015     7.53    12.23  ...      0.89     14.69       4.43
# 1  02/01/2015     3.58     7.15  ...      0.79     15.04       5.64
# 2  03/01/2015    -0.61     6.54  ...      0.84      4.48       6.20
# 3  04/01/2015    -0.63     7.59  ...      0.85      4.35       6.22
# 4  05/01/2015     6.51    10.43  ...      0.91      6.20       5.91
# 5  06/01/2015     3.66     9.95  ...      0.88      8.70       5.93
# 6  07/01/2015     4.58    11.13  ...      0.88     15.50       4.93
# 7  08/01/2015     4.25     7.11  ...      0.83     12.28       5.66
# 8  09/01/2015     4.64    12.31  ...      0.83     19.19       4.54
# 9  10/01/2015     1.85    12.38  ...      0.82     19.92       5.26
#
# [10 rows x 10 columns]

# %%
# fucntion to get weather date

def get_weather(date):
  weather = weatherData.day
  temp = weatherData.tempMedian

  #looping throgh weather data for each day 
  for i in range(0,len(weather)):
    day = datetime.datetime.strptime(weather[i],"%Y-%m-d%")
    if (day == date):
      return temp[i]

# %%
#prep fitting data 
def fit_data():
  x = weatherData.drop('cloudCover', axis = 1)
  x = weatherData.drop('humidity',axis=1)
  x = weatherData.drop('windSpeed',axis=1)
  x = weatherData.drop('visibility',axis = 1)
  y = x.tempMedian
  X = weatherData.drop('tempMedian',axis = 1 )
  newDate = []
  counter = 0
  dates = X.day 
  for day in dates: 
    day = datetime.datetime.strptime(day,"%Y-%m-d%")
    newDates.append(day)
  X.day = newDates
  for day in X.till:
    day = datetime.datetime.strptime(day,"%Y-%m-%d %H:%M:%S")
    new_dates.append(day2)
  X.till = newdate
#train test split of the model 
  X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,random_state=123)
#apply the scaler to the model
  scaler = preprocessing.StandardScaler().fit(X_train)
  X_train_scaled = scaler.transform(X_train)  
#create the pipline
  pipline = make_pipeline(preprocessing.StandardScaler(),
                          RandomForestRegressor(n_estimators=100))
  #define hyper paramenters 
  hyperparameters = { 'randomforestregressor__max_features' : ['auto', 'sqrt', 'log2'],
                  'randomforestregressor__max_depth': [None, 5, 3, 1], } 
#train the data 
  clf = LinearRegression()
  clf.fit(X_train, y_train)
  pred = clf.predict(X_test)
  r2_score(y_test, pred)
  mean_squared_error(y_test, pred, sample_weight=None, multioutput='uniform_average')
  joblib.dump(clf, 'weather_predictor.pkl')

# %%
# weather pred function
def predict_weather():
   clf = joblib.load(clf, 'weather_predictor.pkl')
   print ("."*48)
   print("Enter the date that youd like to predict the weather for")
   print("/n")
   #input details 
   year = input("Year: ")
   month = input("Month: ")
   day = input("Day: ")
   #concatinate all options into a single str 
   day = str(year) + "-" + str(month) + "-" + str(day)
   day = datetime.datetime.strptime(day, "%y-%m-%d")
   date(day - datetime.datetime(2015,1,1)).total_seconds()

   X = [[date]]

# %%
#program menu 
def menu():
  print('.'* 48)
  print ("what would you like to do?")
  print('.'*48)
  print("1. Predict the weather")
  print("2. look at the weather on a specific date")
  print('.'*48)
menu()  

#define the option input
option = input("Enter your option")

#while look which loops through possible option choices
while True: 
  if option == 1 or option == 2 or option == 9:
      break
  option = input("Enter your option")
return option        

# option choice function 
def option():
  if option == 1:
    predict_weather()
  elif option == 2: 
    get_weather(date)

if __name__== "__main__":
  train_data()

  while True:
    option = run_menu()
    if option == 9:
      break
    else:
      option()
# Out:
# ................................................
# what would you like to do?
# ................................................
# 1. Predict the weather
# 2. look at the weather on a specific date
# ................................................
# ERROR! Session/line number was not unique in database. History logging moved to new session 87
# Enter your option1
# Enter your option2
# Enter your option3
# Enter your option5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# ...
