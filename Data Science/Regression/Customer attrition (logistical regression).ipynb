# %%
# prediction of customer attrition using logistic regression 
#DOWNLOAD

# %%
#import libs 
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#import the data set 
from google.collab import files 
upload = files.upload()

# %%
#load data into df 
df = pd.read_csv('')
#display x amount of rows in the data as a test 
df.head(x)
#displaying total rows & col 
df.shape

# %%
#show col names 
df.columms.value

# %%
#check any NA or null fields 
df.isna().sum()

# %%
#show stats on current data 
df.descirbe()

# %%
#data cleaning
cleaned_df = df = df.drop('cusomerID',axis = 1)
cleaned_df.shape

# %%
#total number of churned customers in dataset 
df['churn'].value_counts()
#visualise this count
sns.countplot(df['Churn'])

# %%
# % of the dataset that churned and those that didnt 
retained = df[df.Churn =='No']
churned = df[df.Churn =='Yes']
num_retained = retained.shape[0]
num_churned = churned.shape[0]
#total customers
total = num_retained + num_churned
#printing % of retained customers
print ((num_retained/total)* 100,"% of customers were retained as paying customers")
#% of churned customers
print ((num_churned/total)*100,"% of cusomers were churned")

# %%
#visualise the churn rate split by m | f 
sns.countplot(x='gender', hue = 'Churn', data = df)

# %%
#visualise the tenure and monthly chnages looking for a discrimination of churn 
#histogram to show the reslationship between a customers tenure and the monthly charges
features = ['tenure','MonthlyCharges']
fig,ax = plt.subplots(1,2,figsize(28,8))
df[df.churn == 'No'][features].hist(bins=20,color = 'red', alpha = 0.5,ax=ax)
df[df.churn =='Yes'][features].hist(bins=20,color = 'blue', alpha = 0.5,ax=ax)

# %%
#convert all non numberical fields into num datatypes for analysis
#str ----> num 
for column in cleaned_df.columns:
  if cleaned_df[column].dtype == np.number:
    continue
  cleaned_df[column] = LabelEncoder().fit_transform(cleaned_df[column])
#checking list of cols dtypes
cleaned_df.dtypes

# %%
#scale the data between 0-1 
x = cleaned_df('churn', axis = 1)
y = cleaned_df['churn']
# scaling the feautures of the model 
x = standardScaler().fit_transform(x)

# %%
#spliting the data into training and tetsing 
#80% of the data will be used to train the model 
#20% of the data will be used to test the model 
x_train , X_test, y_train, Y_test = 
train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
#model creatation 
model = LogisticRegression()
#fit the model with the data 
model.fit(x_train, y_train)

# %%
#model eval 
predictions = model.predict(x_test)
#priting the models predictions 
print(predictions)

# %%
#model report 
print(classification_report(y_test,predictions) )
