# %%
#Stock prediction method

# %%
#libs 
import sklearn.svm as SVR
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')

# %%
#import 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7eb8ea7-9816-4a8d-9c4c-caa80df82a77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7eb8ea7-9816-4a8d-9c4c-caa80df82a77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AAPL.csv to AAPL.csv

# %%
df = pd.read_csv('AAPL.csv')

# %%
df
# Out:
#             Date        Open        High  ...       Close   Adj Close     Volume
# 0     2010-05-17   36.385715   36.597141  ...   36.317142   31.439657  190708700
# 1     2010-05-18   36.711430   36.935715  ...   36.051430   31.209614  195669600
# 2     2010-05-19   35.642857   36.131428  ...   35.477142   30.712471  256431700
# 3     2010-05-20   34.554287   34.835712  ...   33.965714   29.404034  320728800
# 4     2010-05-21   33.259998   34.928570  ...   34.617142   29.967972  305972800
# ...          ...         ...         ...  ...         ...         ...        ...
# 2513  2020-05-11  308.100006  317.049988  ...  315.010010  315.010010   36486600
# 2514  2020-05-12  317.829987  319.690002  ...  311.410004  311.410004   40575300
# 2515  2020-05-13  312.149994  315.950012  ...  307.649994  307.649994   50155600
# 2516  2020-05-14  304.510010  309.790009  ...  309.540009  309.540009   39732300
# 2517  2020-05-15  300.350006  307.899994  ...  307.709991  307.709991   41561200
#
# [2518 rows x 7 columns]

# %%
df.shape
# Out:
# (2518, 7)

# %%
#get last recorded price in the df 
actual_price = df.tail(1)
actual_price
# Out:
#             Date        Open        High  ...       Close   Adj Close    Volume
# 2517  2020-05-15  300.350006  307.899994  ...  307.709991  307.709991  41561200
#
# [1 rows x 7 columns]

# %%
#prep for training 
df = df.head(len(df)-1)
df
# Out:
#             Date        Open        High  ...       Close   Adj Close     Volume
# 0     2010-05-17   36.385715   36.597141  ...   36.317142   31.439657  190708700
# 1     2010-05-18   36.711430   36.935715  ...   36.051430   31.209614  195669600
# 2     2010-05-19   35.642857   36.131428  ...   35.477142   30.712471  256431700
# 3     2010-05-20   34.554287   34.835712  ...   33.965714   29.404034  320728800
# 4     2010-05-21   33.259998   34.928570  ...   34.617142   29.967972  305972800
# ...          ...         ...         ...  ...         ...         ...        ...
# 2512  2020-05-08  305.640015  310.350006  ...  310.130005  310.130005   33512000
# 2513  2020-05-11  308.100006  317.049988  ...  315.010010  315.010010   36486600
# 2514  2020-05-12  317.829987  319.690002  ...  311.410004  311.410004   40575300
# 2515  2020-05-13  312.149994  315.950012  ...  307.649994  307.649994   50155600
# 2516  2020-05-14  304.510010  309.790009  ...  309.540009  309.540009   39732300
#
# [2517 rows x 7 columns]

# %%
days = list()
ad_close_price= list()

# %%
df_days = df.loc[:,'Date']
df_adj_close = df.loc[:, 'Adj Close']

# %%
#creating the indi ds
for day in df_days:
  days.append( [int(day.split('/')[1]) ] )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-2cb18ea8c56f> in <module>()
#       1 #creating the indi ds
#       2 for day in df_days:
# ----> 3   days.append( [int(day.split('/')[1]) ] )
#
# IndexError: list index out of range
