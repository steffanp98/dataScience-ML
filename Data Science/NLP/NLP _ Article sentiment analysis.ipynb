# %%
#PROCESS AN ARTCILE FROM THE INTERNET & GIVE BACK A SENTIMENT SCORE

# %%
# !pip install newspaper3k
# !pip install textblob
# !pip install nltk
# Out:
# ...
#      |████████████████████████████████| 215kB 2.9MB/s
# ...
#      |████████████████████████████████| 7.4MB 52.3MB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 194kB 49.8MB/s
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp36-none-any.whl size=7398406 sha256=460fa7a9198520ae3e96725db786bbfc7a8ca5b1ba6dc8241f4863174952c788
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp36-none-any.whl size=13539 sha256=ab59f9753b3c168a8a12ce16908e8a39790b995c28b90e4e8ba265fd186f9f4b
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
# ...
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp36-none-any.whl size=44940 sha256=2eadc64ba42db1c063e418278ce0d3a42984cf282f4f87b02dcfb0d69cf0d182
# ...

# %%
#import lib 
from textblob import TextBlob
import nltk 
from newspaper import Article

# %%
#get article URL 
url = input("please enter atricle url ")
article = Article(url)
# Out:
# please enter atricle url https://www.makeuseof.com/tag/clear-cache-mac/

# %%
#nlp 
article.download() #Downloads the link’s HTML content
article.parse() #Parse the article
nltk.download('punkt')#1 time download of the sentence tokenizer
article.nlp()#  Keyword extraction wrapper
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#Get the summary of the article
text = article.summary

#print text
print(text)
# Out:
# Today we’ll look at why and how to clear caches on macOS, as well as a few apps that make it super easy.
# There are a few other valid reasons you might delete caches beyond a desire for more space:Fix problems with webpages loading outdated assets.
# How to Clear Mac System CachesTo clear system caches specific to your user account:Launch Finder then click Go > Go to Folder in the menu bar at the top of the screen.
# If you want to delete caches associated with another user account, you’ll need to head to that specific user’s cache directory.
# To clear system caches that are shared between user accounts, head to /System/Library/Caches instead.

# %%
#Create Text Blob Object
# textblob obj are like python strings with nlp already applied
obj = TextBlob(text)

# %%
#returns the sentiment of text
#by returning a value between -1.0 and 1.0
sentiment = obj.sentiment.polarity
print(sentiment)
# Out:
# 0.0886904761904762

# %%
#Print if the text was neutral, positive, or negative
if sentiment == 0:
  print('The text is neutral')
elif sentiment > 0:
  print('The text is positive')
else:
  print('The text is negative')
# Out:
# The text is positive
